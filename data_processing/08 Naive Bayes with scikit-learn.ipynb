# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.tail()
# Out:
#                                                 MESSAGE  CATEGORY  \
# 5794  Marc Perkel wrote:\n\n> But - MY POINT IS - ca...         0
# 5795  Update of /cvsroot/spamassassin/spamassassin/l...         0
# 5796  As list administrator, your authorization is r...         0
# 5797  Ciaran Mac Lochlainn stated the following:\n\n...         0
# 5798  Hi, \n\nI'm looking to build a completely sile...         0
#
#                                    FILE_NAME
# 5794  01299.21bf6f0946fe21adc3e99db3e541ee57
# 5795  01336.03d61f76f58b98d6c4c0f4f303994db4
# 5796  00490.9c5dd006a16b1e30c9162ba4b4b75ea8
# 5797  00231.8096ae53e70b1b72b5935b12b823597b
# 5798  00030.cc523265aefc37ee6ce3015d8ff6aa24

# %%
data.sort_index(inplace=True)

# %%
data.head()
# Out:
#                                              MESSAGE  CATEGORY  \
# 0  This is a Multipart MIME message. Since your m...         1
# 1  \n\nDear Sir or Madam\n\n\n\nIn the past you h...         1
# 2  ATTN:\n\n\n\nI am Edward Mulete JR. the son of...         1
# 3  <html>\n\n<head>\n\n<title>Toy</title>\n\n</he...         1
# 4  Suppliers of Computers, Printers, etc. & Consu...         1
#
#                                 FILE_NAME
# 0  00260.c75ce8b8d8bfc55723426979d260bf61
# 1  00242.e030c8b1f053037aeffb062f3a34b523
# 2  00267.ef433fb350170f28a1567cbc24900e53
# 3  00496.1a37de098f6c8847c3c7839d73cc7106
# 4  00031.a78bb452b3a7376202b5e62a81530449

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
all_features = vectorizer.fit_transform(data.MESSAGE)

# %%
all_features
# Out:
# <5799x102694 sparse matrix of type '<class 'numpy.int64'>'
# 	with 704684 stored elements in Compressed Sparse Row format>

# %%
vectorizer.vocabulary_
# Out:
# {'multipart': 63651,
#  'mime': 62140,
#  'message': 61680,
#  'mail': 60312,
#  'reader': 76618,
#  'does': 34891,
#  'understand': 90570,
#  'format': 42435,
#  'legible': 57979,
#  'xx9adb9a99': 97843,
#  '1a5b9adbxx': 2959,
#  'content': 30249,
#  'type': 89371,
#  'text': 86991,
#  'plain': 71912,
#  'charset': 27796,
#  'iso': 53094,
#  '8859': 12828,
#  'transfer': 88556,
#  'encoding': 38472,
#  '7bit': 11595,
#  'k1': 55275,
#  'erotikverlag': 39094,
#  'sucht': 84940,
#  'pornodarsteller': 72499,
#  'wenn': 95168,
#  'du': 36383,
#  'spaß': 83480,
#  'sex': 81443,
#  'hast': 46778,
#  'und': 90516,
#  'nebenbei': 64713,
#  'geld': 44218,
#  'verdienen': 92420,
#  'willst': 95562,
#  'bewirb': 23197,
#  'auch': 20808,
#  'dich': 33934,
#  'wir': 95668,
#  'suchen': 84938,
#  'natürliche': 64487,
#  'frauen': 42729,
#  'männer': 64094,
#  'jeden': 54081,
#  'alters': 18823,
#  'mollig': 62809,
#  'kein': 55788,
#  'problem': 73275,
#  'infos': 51894,
#  'unter': 90983,
#  '0930': 867,
#  '830': 12260,
#  '13': 2107,
#  '22': 3997,
#  'aus': 20887,
#  'österreich': 102517,
#  '01': 309,
#  '90': 13579,
#  '87': 12742,
#  '43': 8047,
#  '54': 9185,
#  'deutschland': 33494,
#  '86': 12651,
#  'eu': 39372,
#  'min': 62159,
#  'callcenter': 26527,
#  'hier': 47513,
#  'ein': 37909,
#  'bild': 23592,
#  'einer': 37914,
#  'produktion': 73351,
#  'das': 32309,
#  'vorstellungsvideo': 93239,
#  'siehst': 82036,
#  'http': 48497,
#  'www': 96531,
#  'web': 94964,
#  'com': 29405,
#  'darsteller': 32304,
#  'index': 51639,
#  'php': 71365,
#  'solltest': 83147,
#  'unserem': 90925,
#  'newsletter': 65065,
#  'interesse': 52351,
#  'mehr': 61492,
#  'haben': 46425,
#  'dann': 32262,
#  'trage': 88511,
#  'bitte': 23734,
#  'newsletr': 65064,
#  'image': 51149,
#  'jpeg': 54779,
#  'base64': 22487,
#  'disposition': 34423,
#  'attachment': 20709,
#  'filename': 41537,
#  'lenkawolfgangk1': 58033,
#  'jpg': 54782,
#  '9j': 14268,
#  '4aaqskzjrgabageasabiaad': 8400,
#  '4rr': 8800,
#  'rxhpzgaasukqaagaaaajaa8bagafaaaaegaaabab': 79637,
#  'agamaaaagaaaabibawabaaaaaqaaabobbqabaaaajaaaabsbbqabaaaalaaaacgbawabaaaa': 17733,
#  'agaaadibagauaaaanaaaabmcawabaaaaagaaagmhbaabaaaasaaaapgbaabtt05zaabeq1it': 17727,
#  'uemxmtbfiabiaaaaaqaaaegaaaabaaaamjawmjowndoxnyaxodoymdo1oaarajqcbqabaaaa': 89895,
#  'ggeaaj2cbqabaaaaigeaackiawabaaaaagaaaacqbwaeaaaamdixmaoqagauaaaakgeaaasq': 44504,
#  'agauaaaapgeaaagrbwaeaaaaaqidaakrbqabaaaaugeaaasscgabaaaawgeaaawsbqabaaaa': 17738,
#  'ygeaaamsawabaaaaaqaaaaqsbqabaaaa0geaaacgbwaeaaaamdewmaggawabaaaaaqaaaaog': 98610,
#  'baabaaaagaqaaakgbaabaaaayamaaawgbaabaaaa2geaaaaaaaabaaaamgaaalqaaabkaaaa': 22109,
#  'mjawmjowndoxnyaxodoymdo1oaaymdayoja0oje3ide4ojiwoju4aaiaaaabaaaaaaaaagqa': 62409,
#  'aacqaaaazaaaacoaaaakaaaaagabaaiabaaaafi5oaacaacabaaaadaxmdaaaaaacgcgkgma': 16132,
#  'aqaaaayaaaapaqiabqaaahycaaaqaqiadaaaahwcaaasaqmaaqaaaaeaaacgkguaaqaaaigc': 19908,
#  'aacgkguaaqaaajacaacgkgmaaqaaaaiaaaayaqiafaaaajgcaacgkgqaaqaaak0caacgkgqa': 16127,
#  'aqaaaesyaaaaaaaau09owqaarenslvbdmtewrsaasaaaaaeaaabiaaaaaqaaadiwmdi6mdq6': 19910,
#  'mtcgmtg6mja6ntgaap': 63493,
#  '8qbogaaaqubaqebaqeaaaaaaaaaaaecawqfbgcicqolaqadaqeb': 13412,
#  'aqebaqebaaaaaaaaaqidbaugbwgjcgsqaaibawmcbamfbqqeaaabfqecawaeequsitfbbhnr': 19933,
#  'wsnjibgzujhxv': 96334,
#  '8arry8nfl1pcxqtnwcoqh14z87dr2inc6dk86': 13040,
#  'eoxublnrbwkkbfx1xx69': 38844,
#  'ugqcc4qp80kvlxtalzu4m6btdnhs4wetjxyxjyfxrrebkkhphrxym5ours': 89995,
#  '9hfu4pwnvt0wo': 14242,
#  'juzrnv7vpi': 55074,
#  'wbcf6j0oagvzoe8qeklwxthmuz1rvbjlngcvp7bx28vajg4vf7plhasik': 94384,
#  'dgk': 33712,
#  'e4bgpyh646vvsotpztsyva6t5u9wdxa': 36973,
#  'hbyijrrfvv94xxtoggpphimftuaa1j7by7q7vysm': 46899,
#  'c1lktk9twnt5fc8m8f8ah': 26022,
#  'ahwbi': 18089,
#  'hv2lmgxopx8h': 48666,
#  'tcyrg4ne7hmuri': 86547,
#  'cx0f3jyousqfbjpt': 31628,
#  'fxlsydomnkq': 43455,
#  'wvxt': 96479,
#  'tdbxo7nwb4': 86555,
#  'ftduh0m': 43121,
#  'newwkxhe0g': 65092,
#  'ae9ap93t7celexekdgdh1r1cj': 17420,
#  'ucowfq8lmqkjuuupgssfuj86gkzjoppmulnf5i8o': 89792,
#  'gvpkx98yjazlcjdqmcsppytd7ip3abj': 46020,
#  'o1': 66550,
#  '58f1rhofaj0sy26rbm6e7kullrszjxb': 9404,
#  'esj': 39198,
#  'hpye': 48340,
#  'pxt9emrp9mkkbexaahqv4gav': 74325,
#  'at5': 20609,
#  'ex9xkmg9ls5735jwwmigweb3fvpnsigyhyplpijryurs9utsiteel7sytwlxesuqkhxkcgn3': 39635,
#  'pncpr3xcs4y2j07nxiom3hfz': 72217,
#  'wak6awgln7hhwxcaa1z5lrfik': 94075,
#  '165ml7m2zpyxg': 2524,
#  'kp8ttvd': 56596,
#  'ic60k9wse': 49315,
#  'zfu3neeh9x6hhevw9jfq5tw3ijyqc5714z8twahp8ciklxueg84zxtryjonyn': 100166,
#  'u9jxh1kfljn0': 89650,
#  'hrc0dpv9otzxi4hsqehhlz19q828c': 48383,
#  'dmyng17oqot0cslziy3mgdquohgd': 34771,
#  'ix3rbd13tl5gwjwarrbw550lwc0leujv5yvgov2lsmzbz0of5vx1c': 53418,
#  'exc242lnccdhp07fhx': 39668,
#  'tppq6pmpkuhytaooz5zx0x4m1itwfblhd3opoaik5ypmzecfx612ysturhnzgk6d': 88388,
#  'pshgseu': 73758,
#  'agm56hmvtpe3oh8f6euneerrcq': 17835,
#  'zovnur3lcjpubgfhwlqf81vz': 100714,
#  'xcqzptttodvctj2': 97070,
#  'hkiv': 47741,
#  'ok1tpe8es054iyv9r2l2qwxge': 67400,
#  'wpuk': 96171,
#  '9bmdxfemd3svk6jcmfdu0oxstjn1fxjbwvs7szbqv': 14103,
#  'oc15jrnjdunvu': 66894,
#  'krkq2cmojzvok68hhnufm9jkx2kjrjzpuzj4s1u6tpbuepjqzbzjburl': 56707,
#  'tdhv752fpaysberaya': 86562,
#  'p6cvalra0spmo14zu7lwsn4zwjkbv1jbb6iku4py': 69010,
#  'wsmrgyd1c9f': 96332,
#  'feqyg': 41173,
#  'f1r18nxvksr': 40272,
#  'h4wmwvt8pj7pf7josb7j8qiki5br6': 46294,
#  'nhxlv9ucdfemnksj2gaswarcq6xjnafqcd8qrjx3pbsu6o7jgerrgj9ca8': 65241,
#  'wihf2pvhg6k48': 95508,
#  '0uvna1xwpr0qivpysb8knlmrify4': 1346,
#  'wdrvz6rahpem': 94868,
#  'w5q8n9adkqlhva': 93826,
#  'wb0': 94355,
#  'wbd': 94391,
#  'fzvo066': 43534,
#  'n6dr4r7agzpxxrmsx8nvbkrcvup1z7g12ekfevq9q2p9ownjxtk': 64216,
#  'defimfkdvhvh0ufx8k': 32977,
#  'is3znu281rexboyre89qg1drlacgmebwohxhhz': 53012,
#  '9avpupu5c0xznqckakxgs0zkyadcocbij': 14081,
#  'brwxx': 25167,
#  '64qln4rkupue52yur5rqdgz': 10283,
#  'h9c16bzatopk7hkryld0580b': 46378,
#  'l9ctn4evlg7dmtjvk': 57328,
#  'rty': 79353,
#  'xaha7gdpft3ravdsuv1atzjpakycmrbiumocgjcpymgjn1roe1uep3zg6exyl221ayjg': 96965,
#  '8lrspubia3mneq': 13309,
#  'w2choeqo': 93772,
#  'bbptax81k8tle4kejs29o6llftkc7sqm': 22640,
#  'njj6dear1fuoulu': 65435,
#  'zsmqkbm52o31ubvi9ns9vj88na8noomtyentxr6fpx': 100893,
#  'coeiwt9bkw4nmqphcplgwx8yjpoev': 29231,
#  'ttxyqkdj1ejzamjck6oyeh3ygmxaimajgap6vuvtps': 89018,
#  'hkjkufn': 47743,
#  'tclbi7nqrxngwthefffpd': 86514,
#  'ydz1': 98492,
#  'vs3': 93409,
#  'lqdv9cdmrlt8vhpevqslv9rtur6nwmy4f2fdpky6hiectyywpvcmcdinwi7jmh3': 59429,
#  'lp0bivdkz6induwitidgmfja': 59376,
#  'ivfi8nlmuaawayvparjzaomohjie': 53327,
#  'hnjifjo9ub4tdga': 47883,
#  'uk': 90148,
#  'oxxgen': 68772,
#  'j3liayerniowjktxsy': 53628,
#  'mttgfhy': 63534,
#  'jtallazexurt0ov': 54901,
#  '75orxd': 11370,
#  'hfhutnmsgu2qzie': 47382,
#  's0xykdslt19emewrnrxhvxmtgdghjwppleqo3t7qg6gescqoh4': 79785,
#  'xnmrp2sb4zk8ctqbjhhub': 97498,
#  'rzrwdj04j': 79729,
#  'evzjyulcxy31m644fmingc8e8flwfexq3udsbnovjdwsh2sopx8a0v1svvozk9': 39564,
#  'a0ykyvf': 15382,
#  'zqjc0uamv84oc45y49etxp3mppedskyj6ch8v5v2wd0cnseynuxs0fu4ipe9ndmn': 100760,
#  'ljstd7rkyiiyftbip4v2': 58840,
#  'uf2x4h09yrw': 89913,
#  't47um77aquaq': 85924,
#  'phpjb6h869nbshyshjny': 71377,
#  'a0zyq': 15383,
#  'wq007lsq': 96175,
#  'gfebs3d2gql9nvidtkjb27j2nds': 44459,
#  'yrmqvjprzivkruncttpdwldvyksw5nxlms5': 99126,
#  '5znqcoxqjk9': 10028,
#  'ad5zrona2ydna9': 17004,
#  'ufrmtcpizuh7uxni8ftxstlc8sju': 89947,
#  'oz7vqkgodxatt0kz69fa26ldsboukgtc18qlmaqywoijaj8sglzsxbxncqnqccr9yc8iszuq': 68825,
#  'tmu9hhseppkbkh4vd7wf': 87956,
#  'trcvnowwpul91n81qz6b48j': 88672,
#  'hx': 48727,
#  '2kvvtbkkx5w31b': 5346,
#  'n1m': 64139,
#  'gw': 46029,
#  'hnx6t3u': 47900,
#  '0irczzumuslvirob0': 1086,
#  'rsb': 79220,
#  'i8jkzyeikwg': 49051,
#  'qr': 75312,
#  'tr9ch7zmdv6ax': 88446,
#  'r7kg6py0wvo4h': 76014,
#  '9fvy6f5s5fh6hqqg2kssbo4ea': 14210,
#  'aj95dj9ynejguyddngma': 18299,
#  'rgfy': 78228,
#  '2ipbsc3qd8f': 5313,
#  'ljbhdq9': 58808,
#  'cb4rhbvb1kfwjdpsny': 27059,
#  '86stfybvu3e3bxeax4f1kklhdpce3i': 12739,
#  'q7ktvttjhsynpkow2v0sd': 74601,
#  'ba9tvbdxpeq1o': 22105,
#  'lne1an7vpgahievi': 59003,
#  'wf6wvdeww8nbbmxy3focyblrl7bf': 95215,
#  'bp': 24730,
#  'f8a5twf': 40420,
#  'chr7l241gt691h2sfthubp': 28090,
#  'abgb6f8a015n9auvp6v1y7lqjfff6hfb5fbt9l': 16366,
#  'ta': 86104,
#  'fa7': 40467,
#  'uo': 91030,
#  '8uemy1gqmvd9fu8vyk5tbyqlgh9ygpf': 13486,
#  'vdx6r9yet9tunmbl2pe': 92276,
#  '2sesrap5flnrgkniz2xh': 5473,
#  'xtyma11drto4hn': 97715,
#  '8rd7a8rfgq6baid3ghba': 13434,
#  'ztz1nabo7knxg7s26fcakaahz6': 100983,
#  'of1kz6c': 67118,
#  'szxwkxxuzb278on9zz9rp': 85787,
#  'tfypz': 87078,
#  'ixe5gtrhmdba9rgsbcs4gaac': 53426,
#  '5yxs': 10002,
#  'mfa': 61782,
#  'q4xutswl9r': 74555,
#  'dq36old': 35365,
#  'ait': 18248,
#  'exz3rup9lyhpp1jyjzk4vpqqx7gn0sgbrw5vltgu': 40112,
#  '03udu': 550,
#  'nf0f': 65112,
#  'bkrcpv': 23873,
#  '5cletfqjp4uhlyhlsmsblickhgi9v': 9525,
#  '3wedzn9ay68hwngdt349z0e9hptyntp81vztd6g7': 7767,
#  '6bp0qv1ytzoxug4jtkfscp42fidqzc7kbvtrse2usxscwsaxv5w3m9': 10594,
#  '76ss9oxrw1': 11409,
#  'arm67': 20146,
#  'tjozmpzuzmqjyjh5ynhh9b': 87779,
#  's2ouji44smpxmccv6t': 79837,
#  'of4ch7kj4g7wswp6hu7': 67120,
#  'anukobbv': 19512,
#  'r7vsrqur67d9s63zrbrth7wusm7fulw2w2bfzrp0mz': 76022,
#  'oura7rer': 68412,
#  'xvq97frhn42he5tie': 97786,
#  '31dhibbxwy1st': 5746,
#  'nrc3yrpocrx0dvnxyc': 66026,
#  'wceyjdmdouelhgth': 94587,
#  '6xsaw4tlral6abzu9lbrh': 11030,
#  'geoe30q9lf8aopfvf9bq8jggwdcfpymh9ouqxmvg': 44325,
#  'x0pucd9ehtvp0fat3px1aycqbl72mlh': 96685,
#  'e6ge7tuw2t': 37025,
#  'qtweddcdxs3dzimnmkgmk4b66lfun6shqgobmo29pregmvvc5pdjtu': 75416,
#  'wvp': 96469,
#  'mt': 63470,
#  '60uj6l9rshnynz3txdavywufqgbaoh51gwbqbnn': 10090,
#  'w7pf': 93860,
#  'af10ns': 17520,
#  'm14ht68nkrudhyt9i': 60005,
#  '6d81wmv9tfoa': 10632,
#  'p9keaappoh9zv5zpsmza0nh5nmgdhhhwkcutjhzcvqvmtjdldzq0w2srkts': 69073,
#  'mbg0sw7ihbx7vywp0ttfdryabt7rlzyc5wf9bm': 61086,
#  '8g6qxnprr8932myzfyswnafvi7kj9hx': 13176,
#  '96wgf5s6pi1nqndtd6p0rxjv9ov0': 13878,
#  'wdsp91vv': 94871,
#  'siyjoftz8ohppu': 82342,
#  'kbzeljiwrbfbdry73jw': 55669,
#  'j00xwuwvurbydftf09oqpfbxfgryx7hpvdvc3bt': 53557,
#  'fqbuzuu6aktdipkli8wozir4rtdh0xu0': 42616,
#  'nz4': 66473,
#  'dsqfxp7p55stdu8qf': 36331,
#  's0': 79768,
#  'wkzcdshpvx2zrbackgjzshdcy7ls9tdft91vt3': 95810,
#  'pp': 72727,
#  'lx': 59852,
#  'e9n': 37120,
#  'o2znzdsnqgx7nol7hvje5zydzv0tm33bv5x6744dddwwzzk5tt1lncmah2pj92tuxq08': 66587,
#  'teqqa2gda3qcnfw5jn5zceacmf0b7nvlphmhloazphp9kvlmuw': 86869,
#  'qvlyvrkum': 75655,
#  'ytm5rzlnuaj': 99203,
#  'llaoo5mnlmpa0ndyj0ettc3bsgu1sseere6r03lcz1su': 58896,
#  'nl0gisu': 65485,
#  'i4s1zqrp3d': 48989,
#  'wx': 96559,
#  'qvmkk': 75657,
#  'rr1dceognr0r9ftdq6htiyxsseabek': 79159,
#  'cwct679iyoojeqjo523edgupjw76llwx1l': 31596,
#  '67nz': 10464,
#  'scw71kqqdtdq7q': 80829,
#  'extb7fz9cpyrnoc6rytpcty': 40029,
#  'ubjcjr0ppz50xlui': 89730,
#  'kh1cx6t67': 56013,
#  '1nj': 3244,
#  'xuuqol': 97754,
#  'v1au9koga8mh1vquja2utrdse': 91794,
#  'wd4rr6jh0py78yqkv2nq9kvbon1rvta5u32': 94733,
#  'wbvcrj1dzstofkznzvrawqxelrc93q1j': 94490,
#  'zsvreg1uqofw9z': 100905,
#  's9gaho5ck9xzuj': 79983,
#  'vv8a66gb': 93564,
#  'blfibp6r4swtbzkc': 23988,
#  'wuqpljxgefu1h': 96426,
#  'u2swue6hzihgq3bswut': 89530,
#  '6l6pfzg8l7pa3khjxl': 10797,
#  'xs8aenyyc8blg50axwvih5vvcge': 97643,
#  '0ddod2khjs3adaw2d0': 978,
#  'fbxwkpxz9nnz5ntwsrpv': 40869,
#  '6iimcje7sic0qwbskhohg3t1vfjy662y': 10752,
#  't4ljaidaz4zfqnttza6j4u8j0rqwracbquf': 85933,
#  '4udx1m': 8842,
#  'ne': 64690,
#  'ipynft': 52808,
#  'lk3rmfplx6ececnkaek9kgpqnkpn': 58862,
#  '8ajk6a2m1vv6gxuizkafdxz': 12997,
#  '6l': 10795,
#  'waxyf1u6ji9te': 94333,
#  '22wh2m4f1q7tp0h': 4209,
#  '5y9i': 9986,
#  'twk3p6xk0nvz2odrpt3aoy539r7fyuj': 89284,
#  'pdop': 70224,
#  '6fttdrodrywwo3eqxwgxrq2': 10704,
#  '2z6a0fh54': 5579,
#  'sdeh8ujnffyma4xy4xrx736t0dwlvtbbdu': 80847,
#  'jlgropc': 54436,
#  'v63umugrgl7pbuhqonqnb11': 91900,
#  'qmwlvxfflu4zwgtsjc': 75151,
#  'brsze': 25140,
#  '579ref68dv': 9364,
#  'zv': 101034,
#  '1fuqro27mjhb8h': 3090,
#  'zsf8awq9l4lpindl49dxs': 100883,
#  'vs': 93408,
#  'mq': 63245,
#  'e4udhk5mx6q4if3ifzh': 36983,
#  'wakf': 94081,
#  'qy': 75763,
#  'v29uecmn': 91815,
#  'amikea7aef': 18987,
#  'ufzqsh5yndub7dt8v8lzh1cp9lpttsnvtdnd8iv5tthqnymefy': 89960,
#  'qlqbooyd6afbj9pdpgv7s9': 75091,
#  'uswn9rpr7pexmate': 91432,
#  'h0': 46207,
#  'ljj3cx8b': 58821,
#  'u6s': 89616,
#  'q7gbaghuvnwzq': 74598,
#  'ufp': 89942,
#  'lp4by2b1z1llixrg1vl40h9r6lvs6d1vpsyptqrgrjpnzy8hj': 59381,
#  'bo9': 24355,
#  'g37pps3wf4rz0m': 43607,
#  'c5fklpz1jzxw': 26249,
#  'aqjhu9dktvsydxgrrreip1d6w3qwgfubfupy': 19947,
#  'nefzxwrttb': 64756,
#  'zczf': 100029,
#  'lvfq2x': 59779,
#  '1i3eezfxc1zhdrtzwdjfzrptqfba': 3133,
#  'xaoynx2pf6bg4nrbbaxpdbazuoa7e': 96977,
#  '5zmz9f36ots': 10026,
#  'fdsko8mommyfqjelzhm8uzcujxnjid7soni4e3yvw21': 41024,
#  'vwwe8rhm2q76t': 93629,
#  'wazllxhfzskr2m': 94350,
#  '5g6j2m': 9620,
#  'ofu': 67233,
#  's1': 79787,
#  '5i7dezi9hdgwpbpzw7lp8fv67jnyag8n3orlbqpesieo': 9655,
#  'xyzw5l6jqgtzzzz': 97933,
#  'copmmrjoyyoxlh803rq3ue7kuk22': 30447,
#  'ou1g': 68370,
#  'm6x': 60103,
#  '37': 6094,
#  'hfy3': 47398,
#  'mdl': 61317,
#  '29zxmfpllld7x5vds': 4843,
#  '6lv': 10816,
#  'ae11l': 17401,
#  'tti1rwrg3cd4cn0': 88989,
#  '5q8': 9827,
#  'sccl56vboc7klmaf8aq0d3o': 80536,
#  'tweiz': 89247,
#  'ak29scujzmk80tsa': 18390,
#  'zx': 101225,
#  'wldzrhix48enathgb': 95824,
#  'uj6i9hgvfeoo0ci': 90117,
#  'hzveozydwgx7omntqomywclgbg6anzblz3u': 48881,
#  'cuhwcya4h8uox1zsmshuj': 31347,
#  '2d7xtgboifx5j95jy37qp2': 4963,
#  'j02x': 53558,
#  'rqkped8mr7w': 79141,
#  '51p': 9064,
#  'v5': 91878,
#  'qj': 74987,
#  'hssrfa911bqqw2ojen6ngz9d2': 48443,
#  '1vufvlfff1bw37a6nxcx5e5plnd1brwxa': 3406,
#  'qxldsyx5lr': 75746,
#  'mwsmbdbi7d84': 63877,
#  'wcagzhus7o72uyorbry2hwmbjr2n6dprfurd': 94551,
#  '22mcnmyz6hdjp': 4169,
#  'j4s3xdfl': 53639,
#  'nh0yeqd1': 65204,
#  'qvozzaza9nxa0j8hct7xagxgtzqwz9xxa1fxjrbr76ca8jkvrc09h': 75660,
#  'gbkv3ld': 44048,
#  'xg3negzptqyzgmhxyzh8m5tyv': 97222,
#  'dvtlfdco6a': 36588,
#  'vptxum1wsodtygigvac4ef6o395n': 93312,
#  'ntq': 66176,
#  'bmvdjtkmnvwhurcr': 24255,
#  'nmd9gxn8tqo4': 65540,
#  '1y6lknatusxxntbex20h': 3453,
#  'javur': 53895,
#  'wcowlxbizde6uyr': 94646,
#  'jqoolxnsh4btqrz': 54824,
#  'vx5zxrie': 93634,
#  'vnzludzcsocutlh0jlth': 93170,
#  'utcxqtrepzlej0wq6wtnxn': 91452,
#  '1fop': 3079,
#  '5p7fwv': 9813,
#  'jtvx60v00xdnx6awu49t9jpbu5jg': 54930,
#  'wdurp2mqrbbwxrgkywtaacf3ob': 94886,
#  'cuz': 31515,
#  'ufvn2vfuajrnlqwe24p9tb': 89957,
#  'aa5l2biwsinsasqjzrz81cctal4y34iwza9endmagpj7dvm59': 15763,
#  '0vctiaisspg4ikoh0tor3bhf': 1355,
#  '0s3lc64qpgb4ukrri6gsdigg9cz0': 1286,
#  'tee6d': 86680,
#  'waklqzr': 94083,
#  'mtp': 63524,
#  's2zpzeskjxnt': 79846,
#  'vlfahf': 93061,
#  'angf': 19252,
#  '9kaoejjtqqhglzlcnnpb24gy29tcgf0awjpbgl0esbpbmzv': 14286,
#  'aaaaafuaaaabaqaaaa8aqqbkag8aygblacaauaboag8adabvahmaaabvahaaaaataeeazabv': 15958,
#  'agiazqagafaaaabvahqabwbzaggabwbwacaangauadaaaaabadhcsu0ebgxkuevhiff1ywxp': 17809,
#  'dhkaaaaabwaaaqeaawea': 33823,
#  '4ajkfkb2jlagsaaaaaaqmafqqdbgonaaaaaaaaaaaaaaaaaaaa': 8421,
#  'ap': 19624,
#  'baiqaeaslcwwleawmebcpdq8xgxqqebqbhxcxfxcxhxemdawmdawrdawmdawmdawmdawm': 22257,
#  'dawmdawmdawmdawmdawmdaerdw8rexevehivfa4odhqudg4odhqrdawmdawreqwmdawmdbem': 32393,
#  'dawmdawmdawmdawmdawmdawmdawmdawmdawm': 32396,
#  '8iaeqgbxgfuaweiaairaqmraf': 13221,
#  'eamcaaamb': 37229,
#  'aqebaaaaaaaaaaaaaaabagmebqybaambaqeaaaaaaaaaaaaaaaabagmebraaagibawqcawac': 19929,
#  'awaaaaaaaaeragmqibiwqcexigrbmhmjm1bcfbeaaqidbgudawmfaqaaaaaaaqaridaheeax': 21216,
#  'uwecupbbcrkbijkrsdghwefg8ujichmsaaefaaaaaaaaaaaaaaaaagbwgjahcrmbaaibbaed': 91608,
#  'pfngioggagfbpapw11pz1ulpxtqb5': 70765,
#  'ocqjhr': 66972,
#  'nzabkzuqi1btgbu1nm1vgonq3mhjsayfsxodbrnjaj18': 66480,
#  'wah6jyrxkabc4dbw': 94038,
#  'tzsujo870w': 89425,
#  'lsqvy9htsrl6yxzmvs6bcgakwa0hwzjoibwbek04pyywiycqw82glzny4uu8uxsywnznl7xi': 59553,
#  '74fw6z9ffpo2wspndqc6ceri9fsm7w5obszpqnbtpgk0ccwgaxcuzopnogmknkokkdgyntwv': 11304,
#  'naetyzaqq5pn': 64304,
#  'opi0jiqerbnv1mdtmaqvjlinezwb4e94bets8': 67844,
#  't4fr0npqajrqgimpaiqim': 85930,
#  'rr3qqjgcgckqlnmgsyslpipwxmp71jqqqmzev6vfu': 79162,
#  'l18tdpj7sm9murgst8o3l7drkx3n53': 57131,
#  '2pa0z29hg9ietzu6ccgpcuzzaaral33jcqzkbzmxkntftinmzs6zl641vittalpn6cwvg5fy': 5421,
#  '8vfn9lu8p2ojl1hc6enbj0cpo3f4h5fl9xpvz9nfydcb61ftqllrneqlncozene7ornvkefq': 13505,
#  'zauzoeubng': 99905,
#  'ycho': 98436,
#  'n00vxivlziykdbrk4fu56xh9uwhrx': 64107,
#  'xwhxj0a656zavm24knykz26obt': 97819,
#  '6efox6babokfgzlkiswqmxr2xllsyedwlcewuu4tuwsfz68flz': 10661,
#  'u8v3dcc': 89641,
#  'ng3y36qyql0jy': 65159,
#  'ljvmzg4vu5ljp6i1zuqlbpk9': 58846,
#  'ja4zulxlt25': 53752,
#  'nlpaitpkxm5uxjnwbugy59tyzlrpkoamjq4': 65504,
#  '37ehuc2sxgfb3w1j6wyvgt1vnwvjth1bvoprsubly9mlw946zszmqnn8vorfl2w3wz1b8': 6137,
#  'mx': 63883,
#  'rpkqxm82pmzcvg8xmklr7t55w6nuraxhh6hb9bpjjpobc8fjqddnohrediqxy9ki405dexu3': 79090,
#  'ebvviilzlfjp5l54': 37395,
#  'zyeh0cnmqlpbfxhwnrgaerbkstmmbzqqof6': 101357,
#  'esy9hjbyvph3vc': 39290,
#  'j6ox': 53678,
#  'i0lyynztkocw0amdkquzm6caw1zz5': 48905,
#  'vpebnqmsscobl2d': 93297,
#  'fzpa4eoj4dwt5atppkkky0zcxn': 43525,
#  'zucxatswkvugzy0zzzz157i': 100997,
#  'y8h65e2ejtexqlm1qdqoulgqwglitoscoadnxs89etn9nbzddd': 98243,
#  '5yrza8epehxd52qusqcoxm43dl75bzsak6czkscomkvfgnndnmrnhnoq10wto7p8zuff0': 9999,
#  'e2': 36901,
#  '2vn6wupjuwaacaaamgpedxj1vwdqkvmisqpvwlbxmwgsc1y5hlo7fkcvy83eatsxlooe9v': 5518,
#  'mbteaptidzzcrrqnaeh5zcfqafnl5fshzyl6q': 61117,
#  'ba': 22091,
#  'kxzgl1': 57015,
#  'llmt': 58919,
#  'p8hovdlzabmalyxa6p5': 69054,
#  'xvuydx': 97790,
#  '2gaiaqeaaquc': 5239,
#  'wcafmyq14fi07vz39vcqtc9fk1wjpz3': 94549,
#  'qs1ykuhmkkkz': 75350,
#  'bg': 23244,
#  'rww6yeswsjjz': 79608,
#  'fyawrmnoggggffwuqku4q7gznyi0kh95flaqyjbwx96rrxi7suf0qf1oc': 43485,
#  '66zbflyk13msz8kby7f2smn3kot9vkz': 10430,
#  'pznjlcjrjzh9uk7u7qhldzms': 74403,
#  'ieti1hdhmzrg': 50246,
#  'zmt775z': 100609,
#  'swsjmewsu1syzcw7jcwirhzzsvbwbs': 85515,
#  'jb5rhzccrrsvc': 53915,
#  'ws3bijbhywsqrjk': 96305,
#  'pf8': 70732,
#  'r0kqth4tii4vg': 75860,
#  'ioxfjcvbzxxripvedr9ziitpy1vxla': 52702,
#  'gdlstbkloxkylmn8hwtarn5tvdj': 44144,
#  '8i7g9ukvbnbrwpzzbszugsi80unfk8f1611t': 13219,
#  'tqczmvfc9der3qfbzstujj8klbvwyfufkz0': 88420,
#  'ylrllejskck71jy1iklptpfvsoefixuzpjsqvcv77f5gpbhxnuty0t6yrwhxuc8g5mfsxvvd': 98826,
#  'uvrwu4ioiqecz44tyllao9v': 91582,
#  'ablsbq4kqje9bgbwy0qjdf4ayt823zrcrrwcvv7vv8o1cvrh': 16404,
#  '18bpwzzlwvur4bufwpjuizaxl91rcsicxamve5b': 2778,
#  'ahzeaqtjrpftrwtbjvee2egrfwxp1wjm': 18093,
#  '9ffa3daplw3sejruq': 14204,
#  'nf9a6tpjtjslzoy': 65117,
#  'eqpr086eethxq9wx9ysogw2n5soj': 38960,
#  'uyelk': 91697,
#  'sg3': 81523,
#  'vdzoeazhzs': 92281,
#  'yrxq3oymoxjqq11ci9blgfflnsvy5kt8pdieino3': 99134,
#  'afbgbknrltji1pbshssu': 17539,
#  'qeyci2wemnqpa9mrwkkexvrrmyub6jfvbjx0qu7x4vp8kixqvrgtvwlv1gm': 74841,
#  'zn5': 100636,
#  'rcvfhk': 76518,
#  'wc17j1': 94521,
#  'edtpk4u1raytxyrjonjfrbp0fnrl2v8itcwczke8ah5vfwuds3': 37589,
#  'dv3msvrizxhjw': 36552,
#  'hxikqgt0bgfmsf3ctw1hcsaxlffa': 48739,
#  '8ntv4r0': 13351,
#  'l9j7fcabl6vpyrjyklrwi0vb5drsvyt4vd3': 57330,
#  'kvq': 56930,
#  'h9josvw3z1x3slauwovuicnjj2mk5n9uf0k3nvme6ilveyykwylcqi3uhhq': 46382,
#  'x9rglhky': 96902,
#  'omctdk1nwccnwj': 67556,
#  'djlwlxl5tlywsyepimj6faynfcdvri9e7x8vpzmjbvpzwsebcqmrwsccc': 34611,
#  'ntjf5dx8zhyy5ki12z8avs6mp7b': 66160,
#  'rre6vm5emsok8ffdz0qov0idmqkd9rzbbgrrarq65jbu': 79171,
#  'zcvfbkeygxvi015h6qpy7r4': 100024,
#  'qtl1ytutg4f0i1am2nowwqo22934j4pcunlxtrh5swfsei2p': 75404,
#  'yloteawqz8cpfx': 98825,
#  'fl8huia19y9tn0mixrgjrmwkq9el2pdx': 41842,
#  'k36igxgolwd87pj0yukhj0sj': 55329,
#  'pjnbxk4': 71739,
#  'f1': 40254,
#  'jsvilrjfreznprrmujnti9k': 54890,
#  '5y0icnx5etcl': 9983,
#  'cqty1nt89izpsvojfblxbj8': 30852,
#  'vrme85k': 93386,
#  'rby1npystsyy6mii2mk3fpzst6oowma3gi8lbbporzyudsd3clfyxkxkx': 76462,
#  'ncuayj': 64622,
#  '9rrx7lypt1rgnkknoyst0bh2f4mdi3il6vwyq': 14467,
#  'fpzma3k9sm3wpsdx0jg2cjignezkph4dxd': 42606,
#  'wsd82rrltcnzjki1ej1': 96316,
#  'o1k6jayj7mwrlrp9e8rszhy0lsx9m2miqtkjej9t40kkb2stoylt': 66559,
#  '7l1ktwhjfgytkkfzdulszm9pujgl1': 11806,
#  'n0rssssdz2syx4ol': 64123,
#  's2tdrkosymhdwuqtcj8w8uvuu': 79840,
#  '6vq2t51kknbazo': 11004,
#  'p1m': 68906,
#  'ke5osjlqxuvkqtgz7feqvnrbh6b0yyvqydelyy7lv5yaxiq97reps': 55752,
#  'vyqha2z9ixvs15svwxjgthri2nnocurmt2my3euvohx8flyp2ssipmlrjzl3nsa': 93695,
#  'nbbxsekk': 64540,
#  'jengtyx5wlijkci': 54107,
#  'qdpmeg3iygnrjq9zlir6jgzrqvzkxdhuqtsex6yses1immfk': 74797,
#  'nwp4n8d': 66388,
#  'wawq8gnpbyrb6e91kyv1gxszwl': 94327,
#  'xpns78ortbg9gptjuiqlzeizty': 97558,
#  '7qvpxpj8j5hyhwt': 11897,
#  'vxykieeb': 93669,
#  'bq25ecstjaf5s8dofc': 24772,
#  '7oqtj1y9ovmore3efmtel4jrozyetyqqiencbw2ypt': 11863,
#  'lfk': 58179,
#  'r49mv': 75957,
#  'xc0er1exnmtnaz0uxbxizdojbdpj5pox1dstissrvtnkgxy3kslgl': 97030,
#  '3jfq9jfq': 7535,
#  'x6v830kle9cstypeyy2xtc83tjpwro': 96836,
#  '26d2syze0rrls26sdpjbxoj40kavjg0fidrdx5chj': 4592,
#  'w1pq': 93762,
#  'wi0y': 95457,
#  'b1zxyxj8khe5oht7tf9jgljjz8txrjpwv': 21650,
#  'q0xva9kaynjzva2': 74465,
#  'bzyshzcif9jk': 25960,
#  'hfbyvty2vyvt1bfroj2txoyg9jgmqvegv': 47376,
#  'di09bpkfnyor9plfsy2k1x0rrjfrd3lyxe1pf9': 33881,
#  'tpglt8ubalapkp7rv2fqzcnupatn': 88376,
#  '9oacaecaaefauwfa27vsb7r27gdzg': 14367,
#  'xfrsh03ueqqw9': 97207,
#  'dhkjnveioq30w9zj61u2srtfypy2t0h056b6dzjo': 33826,
#  'cona3qgjxiqpsfuv2c3zpxylbd': 29771,
#  'ewwx': 39617,
#  'vxo': 93655,
#  'utl3pufyiq3gq9dghms': 91486,
#  'xe9d6xe4m4xoknbkpoxshansrsqh9fb2hrvlp8iehxopyyt2': 97127,
#  'c6r3': 26285,
#  'wd': 94717,
#  '2gaiaqmaaquc7bd7si89pwsiudpwny8dluuxsjaketwxlp1w5atba5t30ej': 5261,
#  'bfjp': 23219,
#  'w5awrwk1jovutlckopaupj3lsmzo1dhtwbv6df0vol2ufanejfye9gxdcti1knzjovmkr2d3': 93818,
#  'wa3yvfyw20ulslapsql6v672y14lfewshlay9h7xut2tfkwtpz1u9ka2f0uch9ecp0bhpz': 93911,
#  'usyvrdo2cnpw0cc7gxi6nt6cctotnoui6nhocmcn2mhejrifqe2u': 91436,
#  '2gaiaqicbj8ch': 5260,
#  '2gaiaqmcbj8cd7bbqn': 5266,
#  '2gaiaqebbj8c': 5251,
#  'op4h4obwt': 67763,
#  'facjqshwlttsnpbmvja6bbqcbqvbu': 40517,
#  'rjyqpeb1plna6aqp9ofpmbdewtdpdiv5doly0vmbv': 78581,
#  'x8ttv49ra': 96886,
#  '6m1mebdnyr3zz3c8dq': 10823,
#  'fdu2m3w5': 41026,
#  'a9yatbbiirzsdve2qyvtaeewmphiq1udlvh3ht': 15738,
#  'jhjtxyr2tglfy3rugiij8dtv': 54254,
#  'xhr': 97267,
#  'sx': 85538,
#  'ua92gaxwt4mw4yr6rnnqmytkqcu5ygosoxuzi1rarxpbt1q3nhy': 89670,
#  'emhn03': 38317,
#  'ah': 17948,
#  '5gxyvsqxzdbkgvxarluxqnxmt2i55k0y': 9637,
#  'czdmfsf1udmpmemx': 31805,
#  's8bxinmoiry0z7rkaooovx': 79955,
#  '36ltomdapx3p2bsbhi5p': 6088,
#  'durhxw3z2n9ynw': 36513,
#  'kx12seb4d1hra3tp': 56974,
#  'jj2ufoibuh6': 54347,
#  'za6e1v': 99843,
#  '88v3kc3crdpn': 12850,
#  '3t8nt7pzivqksnnvtp3hpora0dyfdz8s8vyv5buvva2oz9kly2panu1vqyz': 7710,
#  'k8t1d00rntay05xhry': 55435,
#  's0z8vy6frskzvlb6j8itzmmcbrixt0tmbrz5bcv': 79786,
#  'snpcnkogue4t2': 82980,
#  'gfubcawvwajkf6r': 44478,
#  'ivj5wpe0lngzwdr8zhmmlj3pcc5padxl68hpbjlrmefucvy3w108dxlp': 53334,
#  'tp7nbcmjwkcsvephieaasxsc8a7pp7xps0ye4hdc6w6oe2gzwlk': 88356,
#  '5mezl5ffjywmlnjjj8kl': 9743,
#  'kwwzhqfqrosbdjfdnoosbkwum6swxkfswz3fdmql7g4wjzadbtcqnz': 56970,
#  'ccfrmymtnxg44khuf': 27157,
#  'vryl4rilw6nbqr3rffilg5m4vixvnxwlr3bzkheabm0uixfuvcfl3vc8oi5f6g2syiwca8uv': 93405,
#  'dtaru': 36352,
#  '6b': 10579,
#  '9oacaebawe': 14365,
#  'iq0r': 52815,
#  'wc7p8y0lkqwhulac6yjiwwh': 94541,
#  'wb7v': 94369,
#  'njqcjaaed9aneou2bd': 65446,
#  'b99b': 22069,
#  'wduel391': 94882,
#  'qytgg5fwgbppafdeazd': 75788,
#  'zeyep': 100137,
#  'akt0alyxb5': 18477,
#  'gg0zwmbw3ljro': 44486,
#  'li8ad': 58303,
#  'jva3j29v50duq0muvae7qdqh': 55084,
#  'wdqq0l7chpwrx': 94860,
#  'zuspwmefejwybvqlhuttoh': 101024,
#  'anjox': 19312,
#  'mk': 62457,
#  'zb68yubtibe0q5rq576v95sx2h': 99924,
#  '8teuyhzemg2ix0qlyin3ry': 13472,
#  '4subpv6hnfjia4hiju8qjt': 8822,
#  '86ch859qyn6ndty09mhd0e7': 12735,
#  'adsclmfqnqfrome': 17284,
#  'z9pmhoaeqvdu4jezllympp9o8ieq8znd': 99835,
#  'i9ixfaimwdp7l': 49067,
#  'ojsim7cmi1zhf199sxokg8zxevc6svk3': 67387,
#  'rmla5rgsver': 78704,
#  'a4fndj64ij8x': 15561,
#  'htbsyc57qrjs9iwbzxcfred943pbz8eosmezvz8z6r': 48460,
#  'aculsvep5xjgmrerex0cxfryfr4l': 16950,
#  'oletxukd7s2wpcqkrzrd3jvz3mszc55xaymfmozmag': 67484,
#  'st4': 84001,
#  'p8aujuzf8qxqa75': 69050,
#  'rgb9fma': 78220,
#  'vj6zcrme4nqvdwgzgnw2yfrg': 92980,
#  'wd8mway5jv1niupojp': 94748,
#  '5ic8warenkhmktmy4hvltu': 9658,
#  'kjx': 56259,
#  'slyqnk': 82712,
#  '8jcgvzpjbnsx9bbah17r3j4': 13249,
#  '2ma6fbdpf8z': 5372,
#  'mn9ourjsoqgp9': 62616,
#  'q415xdujj9e0z8j': 74541,
#  'kzleoxkjx8syt1mjp2': 57090,
#  '5b7pps4k9': 9485,
#  'rwdth5': 79588,
#  '7b': 11581,
#  '1et24': 3064,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY, test_size=0.3, random_state=88)

# %%
X_train.shape
# Out:
# (4059, 102694)

# %%
X_train
# Out:
# <4059x102694 sparse matrix of type '<class 'numpy.int64'>'
# 	with 485758 stored elements in Compressed Sparse Row format>

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# **Challenge** calculate the following for the test dataset:
#                 the number of documents classified correctly <br>
#                 the number of documents classified incorrectly <br>
#                 the accuracy of the model.

# %%
prediction = classifier.predict(X_test)

# %%
correct_docs = (y_test == prediction).sum()
print('Dcos classified correctly', correct_docs)
# Out:
# Dcos classified correctly 1648

# %%
numdocs_wrong = X_test.shape[0] - correct_docs
print('Docs classified incorrectly', numdocs_wrong)
# Out:
# Docs classified incorrectly 92

# %%
accuracy = correct_docs / (X_test.shape[0])
print('the accuracy of the model is {:.2%} '.format(accuracy))
# Out:
# the accuracy of the model is 94.71%

# %%
## or....

classifier.score(X_test, y_test)
# Out:
# 0.9471264367816092

# %%
recall_score(y_test, prediction)
# Out:
# 0.8504504504504504

# %%
precision_score(y_test, classifier.predict(X_test))
# Out:
# 0.9812889812889813

# %%
f1_score(y_test, classifier.predict(X_test))
# Out:
# 0.9111969111969112

# %%
example = ['get the viagra for free now!', 'need a mortgage? reply to arrenge a call with a specialist and get a quote', 'Could you please help me with the project for tomorrow?', 'Hello Jonathan, how about a game of golf tomorrow?', 'Ski jumping is a winter sport in which competitors aim to achieve the longest jump']

# %%
vectorizer.transform(example)
# Out:
# <5x102694 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24 stored elements in Compressed Sparse Row format>

# %%
doc_term_matrix = vectorizer.transform(example)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([1, 1, 0, 0, 0])
